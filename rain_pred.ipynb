# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv("train.csv")
df_train

# %%
df_train.info()

# %% [markdown]
# Data visualisation

# %%
import seaborn as sb

cols= ["#C2C4E2","#EED4E5"]
sb.countplot(x= df_train["RainTomorrow"], palette= cols)

# %%
#correlation
import matplotlib.pyplot as plt

df = df_train.select_dtypes(include=['float64'])

corrmat = df.corr()
cmap = sb.diverging_palette(260,-10,s=50, l=75, n=6, as_cmap=True)
plt.subplots(figsize=(18,18))
sb.heatmap(corrmat,cmap= cmap,annot=True, square=True)

# %% [markdown]
# Data preprocessing

# %% [markdown]
# Data cleaning

# %%
df_train.isnull().sum()

# %% [markdown]
# Handling missing values

# %%
#replacing the missing values :
#numerical values with the median and non numerical ones with the mode

for col in df_test.columns:

    if df_train[col].isnull().sum() > 0:
        
        if df_train[col].dtype == 'float64':

            val = df_train[col].median()
        else:

            val = df_train[col].mode()[0]  #the most frequent value
        

        df_train[col] = df_train[col].fillna(val)


df_train.isnull().sum().sum()

# %% [markdown]
# Encoding

# %%
#turning non numerical values into numerical

df = df_train.select_dtypes(include=['object'])
df
# Out:
#              Date            City WindGustDir WindDir9am WindDir3pm RainToday  \
# 0      2010-01-01         Algiers         NNE         NW        WNW       Yes
# 1      2010-01-02           Setif           W          S          W       Yes
# 2      2010-01-03  Sidi Bel Abbes           W        SSW         SW        No
# 3      2010-01-04          Skikda          SW        ENE        NNW        No
# 4      2010-01-05          Skikda           W          E         NW        No
# ...           ...             ...         ...        ...        ...       ...
# 76667  2014-12-27          Annaba         NNW          S        NNW        No
# 76668  2014-12-28         Algiers          NW        ESE        WNW        No
# 76669  2014-12-29  Sidi Bel Abbes           W          E          W        No
# 76670  2014-12-30          Skikda           N          E        WNW       Yes
# 76671  2014-12-31           Setif           N        ESE          N       Yes
#
#       RainTomorrow
# 0              Yes
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 76667           No
# 76668           No
# 76669          Yes
# 76670          Yes
# 76671          Yes
#
# [76672 rows x 7 columns]

# %%
df_train = pd.read_csv("train.csv")

#encoding
df_train.replace({'Yes':1, 'No':0}, inplace=True)

df_train['WindGustDir'] = pd.factorize(df_train['WindGustDir'])[0] + 1
df_train['WindDir9am'] = pd.factorize(df_train['WindDir9am'])[0] + 1
df_train['WindDir3pm'] = pd.factorize(df_train['WindDir3pm'])[0] + 1

#City:
df_train['City'] = pd.factorize(df_train['City'])[0] + 1

#Date : extracting each component
df_train['Date'] = pd.to_datetime(df_train['Date'])

#year, month, day as separate features
df_train['Year'] = df_train['Date'].dt.year
df_train['Month'] = df_train['Date'].dt.month
df_train['Day'] = df_train['Date'].dt.day
df_train = df_train.drop('Date', axis=1)

# %% [markdown]
# Splitting data

# %%
from sklearn.model_selection import train_test_split

x = df_train.drop(["RainTomorrow"], axis=1)
y = df_train["RainTomorrow"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, shuffle=False)

# %% [markdown]
# Balancing data

# %%
from imblearn.over_sampling import RandomOverSampler
# since the data is imbalanced
# balancing the data by adding repetitive rows of minority class
ros = RandomOverSampler(sampling_strategy='minority',random_state=22)
X, Y = ros.fit_resample(x_train, y_train)
# Out:
# (94276,)

# %% [markdown]
# Training the model

# %%
import xgboost as xgb
import optuna

from sklearn.metrics import f1_score

# %%
def objective(trial):
    param = {
        'booster': 'gbtree',
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    }

   
    model = xgb.XGBClassifier(**param, use_label_encoder=False)
    model.fit(X, Y)

    
    y_pred = model.predict(x_test)

    f1 = f1_score(y_test, y_pred)
    return f1

# %%
study = optuna.create_study(direction='maximize')  # maximum f1
study.optimize(objective, n_trials=30,timeout=1800)  # sets of hyperparameters
# Out:
# [I 2024-10-12 19:31:22,342] A new study created in memory with name: no-name-4746d3a3-e13a-4bea-b74b-51b64873bdce
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:31:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:31:37,260] Trial 0 finished with value: 0.6422752184861502 and parameters: {'learning_rate': 0.1491420350074782, 'max_depth': 8, 'n_estimators': 305, 'min_child_weight': 8, 'gamma': 1.551124786348805e-07, 'subsample': 0.8810855008893894, 'colsample_bytree': 0.9941482656268432}. Best is trial 0 with value: 0.6422752184861502.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:31:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:32:07,832] Trial 1 finished with value: 0.6385542168674698 and parameters: {'learning_rate': 0.0002858062999971712, 'max_depth': 10, 'n_estimators': 387, 'min_child_weight': 6, 'gamma': 0.00016749058312820212, 'subsample': 0.5076118432013825, 'colsample_bytree': 0.7267468748035661}. Best is trial 0 with value: 0.6422752184861502.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:32:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:32:12,700] Trial 2 finished with value: 0.6467689708573842 and parameters: {'learning_rate': 0.08374223795077342, 'max_depth': 12, 'n_estimators': 85, 'min_child_weight': 8, 'gamma': 0.009981564247502637, 'subsample': 0.5390143291662342, 'colsample_bytree': 0.781722661054054}. Best is trial 2 with value: 0.6467689708573842.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:32:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:32:30,500] Trial 3 finished with value: 0.6433828449083366 and parameters: {'learning_rate': 0.003094559565167565, 'max_depth': 8, 'n_estimators': 489, 'min_child_weight': 10, 'gamma': 0.9008551295871631, 'subsample': 0.5520446812465629, 'colsample_bytree': 0.8502068003956301}. Best is trial 2 with value: 0.6467689708573842.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:32:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:32:39,109] Trial 4 finished with value: 0.6354964396076851 and parameters: {'learning_rate': 0.00817709263116311, 'max_depth': 3, 'n_estimators': 496, 'min_child_weight': 6, 'gamma': 0.21946989648083934, 'subsample': 0.8527419624543984, 'colsample_bytree': 0.9042031042228755}. Best is trial 2 with value: 0.6467689708573842.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:32:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:32:47,922] Trial 5 finished with value: 0.6265711582646304 and parameters: {'learning_rate': 5.933793750201541e-05, 'max_depth': 6, 'n_estimators': 313, 'min_child_weight': 8, 'gamma': 0.04482915171782064, 'subsample': 0.8212438118573866, 'colsample_bytree': 0.9743275515527144}. Best is trial 2 with value: 0.6467689708573842.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:32:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:32:57,018] Trial 6 finished with value: 0.6310575635876841 and parameters: {'learning_rate': 9.754606460876677e-05, 'max_depth': 7, 'n_estimators': 290, 'min_child_weight': 9, 'gamma': 2.9855538259986565e-05, 'subsample': 0.9805006613998852, 'colsample_bytree': 0.7214052664453682}. Best is trial 2 with value: 0.6467689708573842.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:32:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:33:01,307] Trial 7 finished with value: 0.6494874715261959 and parameters: {'learning_rate': 0.10903052691792497, 'max_depth': 11, 'n_estimators': 87, 'min_child_weight': 7, 'gamma': 0.28857686193726706, 'subsample': 0.6636474140285564, 'colsample_bytree': 0.7312209108953345}. Best is trial 7 with value: 0.6494874715261959.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:33:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:33:05,684] Trial 8 finished with value: 0.6089474446213986 and parameters: {'learning_rate': 0.00020073606555839443, 'max_depth': 3, 'n_estimators': 207, 'min_child_weight': 10, 'gamma': 0.4214549868448403, 'subsample': 0.9532351206145553, 'colsample_bytree': 0.949283661240501}. Best is trial 7 with value: 0.6494874715261959.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:33:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:33:27,331] Trial 9 finished with value: 0.6420664206642066 and parameters: {'learning_rate': 2.1494819648560725e-05, 'max_depth': 11, 'n_estimators': 318, 'min_child_weight': 6, 'gamma': 9.227328008079528e-06, 'subsample': 0.7686831907382043, 'colsample_bytree': 0.8014697780394477}. Best is trial 7 with value: 0.6494874715261959.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:33:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:33:30,231] Trial 10 finished with value: 0.5748043578333589 and parameters: {'learning_rate': 0.9495097518813093, 'max_depth': 10, 'n_estimators': 56, 'min_child_weight': 2, 'gamma': 0.00415847876373209, 'subsample': 0.6480889502502596, 'colsample_bytree': 0.5546745397629962}. Best is trial 7 with value: 0.6494874715261959.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:33:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:33:34,875] Trial 11 finished with value: 0.6464995678478824 and parameters: {'learning_rate': 0.05390859907299891, 'max_depth': 12, 'n_estimators': 62, 'min_child_weight': 3, 'gamma': 0.005086866181751066, 'subsample': 0.6375281992290296, 'colsample_bytree': 0.632812876137101}. Best is trial 7 with value: 0.6494874715261959.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:33:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:33:44,590] Trial 12 finished with value: 0.6517053004576997 and parameters: {'learning_rate': 0.0535211802212119, 'max_depth': 12, 'n_estimators': 161, 'min_child_weight': 4, 'gamma': 0.009320161978489908, 'subsample': 0.6503068887714993, 'colsample_bytree': 0.6591376980120444}. Best is trial 12 with value: 0.6517053004576997.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:33:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:33:53,746] Trial 13 finished with value: 0.6462547840349918 and parameters: {'learning_rate': 0.010772823203033195, 'max_depth': 10, 'n_estimators': 157, 'min_child_weight': 4, 'gamma': 0.001015570071715168, 'subsample': 0.6837270083960292, 'colsample_bytree': 0.6540918381479378}. Best is trial 12 with value: 0.6517053004576997.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:33:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:00,164] Trial 14 finished with value: 0.5953637090327738 and parameters: {'learning_rate': 0.8252798077109854, 'max_depth': 12, 'n_estimators': 159, 'min_child_weight': 4, 'gamma': 0.07567222144637112, 'subsample': 0.7184978819458578, 'colsample_bytree': 0.5137336470496978}. Best is trial 12 with value: 0.6517053004576997.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:07,019] Trial 15 finished with value: 0.636424461394353 and parameters: {'learning_rate': 0.0014576743695581043, 'max_depth': 9, 'n_estimators': 135, 'min_child_weight': 1, 'gamma': 0.0005051923652982313, 'subsample': 0.6110168481450191, 'colsample_bytree': 0.6453180448980497}. Best is trial 12 with value: 0.6517053004576997.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:12,374] Trial 16 finished with value: 0.6409752261108926 and parameters: {'learning_rate': 0.02972407686558924, 'max_depth': 5, 'n_estimators': 221, 'min_child_weight': 5, 'gamma': 2.206743308804615e-06, 'subsample': 0.7513104655541631, 'colsample_bytree': 0.590002639072052}. Best is trial 12 with value: 0.6517053004576997.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:17,171] Trial 17 finished with value: 0.631768953068592 and parameters: {'learning_rate': 0.2547214636590402, 'max_depth': 11, 'n_estimators': 112, 'min_child_weight': 7, 'gamma': 0.024787496958031625, 'subsample': 0.5819472149643725, 'colsample_bytree': 0.6962351270071326}. Best is trial 12 with value: 0.6517053004576997.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:26,951] Trial 18 finished with value: 0.6554919596620332 and parameters: {'learning_rate': 0.021355413756704068, 'max_depth': 9, 'n_estimators': 216, 'min_child_weight': 4, 'gamma': 0.0016635979346675872, 'subsample': 0.6610203644235196, 'colsample_bytree': 0.8367211869715874}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:36,827] Trial 19 finished with value: 0.6534788540245566 and parameters: {'learning_rate': 0.021865849016406477, 'max_depth': 9, 'n_estimators': 223, 'min_child_weight': 3, 'gamma': 5.5611494735891345e-08, 'subsample': 0.703280578897134, 'colsample_bytree': 0.8501534785078753}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:45,007] Trial 20 finished with value: 0.6336927223719676 and parameters: {'learning_rate': 0.0009941372759607783, 'max_depth': 7, 'n_estimators': 224, 'min_child_weight': 2, 'gamma': 1.2143829407202102e-08, 'subsample': 0.7923889957794048, 'colsample_bytree': 0.8593962817515042}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:34:57,437] Trial 21 finished with value: 0.6530501089324618 and parameters: {'learning_rate': 0.012181580790567864, 'max_depth': 9, 'n_estimators': 253, 'min_child_weight': 4, 'gamma': 8.498220932705515e-07, 'subsample': 0.7164975536068185, 'colsample_bytree': 0.8279566371403063}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:34:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:35:10,638] Trial 22 finished with value: 0.6545603495357728 and parameters: {'learning_rate': 0.015390110235538306, 'max_depth': 9, 'n_estimators': 263, 'min_child_weight': 3, 'gamma': 3.173335065323699e-07, 'subsample': 0.7076698329472807, 'colsample_bytree': 0.8358804186580825}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:35:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:35:24,918] Trial 23 finished with value: 0.6547321676380794 and parameters: {'learning_rate': 0.022388177751740793, 'max_depth': 9, 'n_estimators': 361, 'min_child_weight': 3, 'gamma': 1.9730599527556853e-08, 'subsample': 0.7013174174294922, 'colsample_bytree': 0.9041152666901529}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:35:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:35:40,407] Trial 24 finished with value: 0.6411149825783972 and parameters: {'learning_rate': 0.0028453372315713414, 'max_depth': 8, 'n_estimators': 362, 'min_child_weight': 1, 'gamma': 1.4963096905270768e-08, 'subsample': 0.6092555925152319, 'colsample_bytree': 0.8998625202975353}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:35:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:35:53,610] Trial 25 finished with value: 0.6407792900987457 and parameters: {'learning_rate': 0.0069234594157686685, 'max_depth': 6, 'n_estimators': 431, 'min_child_weight': 3, 'gamma': 1.02096681143891e-07, 'subsample': 0.7386274593654762, 'colsample_bytree': 0.9122216730303763}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:35:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:36:05,446] Trial 26 finished with value: 0.6235142948923867 and parameters: {'learning_rate': 0.27891103527636957, 'max_depth': 9, 'n_estimators': 363, 'min_child_weight': 2, 'gamma': 7.020848610849722e-07, 'subsample': 0.8042779567138457, 'colsample_bytree': 0.7777457042630181}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:36:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:36:20,319] Trial 27 finished with value: 0.6433699038331302 and parameters: {'learning_rate': 0.0008172568007660313, 'max_depth': 10, 'n_estimators': 253, 'min_child_weight': 5, 'gamma': 2.5849503812843274e-05, 'subsample': 0.6828948254229693, 'colsample_bytree': 0.8785533643867403}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:36:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:36:34,120] Trial 28 finished with value: 0.6524822695035462 and parameters: {'learning_rate': 0.020334412446980366, 'max_depth': 7, 'n_estimators': 417, 'min_child_weight': 3, 'gamma': 3.6243417218958576e-07, 'subsample': 0.6078491318022959, 'colsample_bytree': 0.9525428199476289}. Best is trial 18 with value: 0.6554919596620332.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:7: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\563567884.py:11: FutureWarning:
#
# suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:36:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#
# [I 2024-10-12 19:36:48,464] Trial 29 finished with value: 0.6412766528094408 and parameters: {'learning_rate': 0.0039930357007053685, 'max_depth': 8, 'n_estimators': 336, 'min_child_weight': 5, 'gamma': 4.136799246139158e-06, 'subsample': 0.8433678977594784, 'colsample_bytree': 0.8128791559217172}. Best is trial 18 with value: 0.6554919596620332.

# %%
print("Best F1 Score: ",study.best_value)
best_params = study.best_params
# Out:
# Best F1 Score: 0.6554919596620332
# Best Hyperparameters: {'learning_rate': 0.021355413756704068, 'max_depth': 9, 'n_estimators': 216, 'min_child_weight': 4, 'gamma': 0.0016635979346675872, 'subsample': 0.6610203644235196, 'colsample_bytree': 0.8367211869715874}

# %%
best_xgb_model = xgb.XGBClassifier(**best_params, use_label_encoder=False)

#retraining the model that has best params
best_xgb_model.fit(X, Y)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning:
#
# [19:45:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8367211869715874, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.0016635979346675872,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.021355413756704068,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=216, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# Evaluating the model

# %%
y_test_pred = best_xgb_model.predict(x_test)
test_f1 = f1_score(y_test, y_test_pred)
print("Test F1 Score: ",test_f1)
# Out:
# Test F1 Score: 0.6554919596620332

# %% [markdown]
# Predicting the test data

# %%
#reading the df test
df_test = pd.read_csv("test.csv")

# %% [markdown]
# Handling missing values

# %%
#replacing the missing values :
#numerical values with the median and non numerical ones with the mode

for col in df_test.columns:

    if df_test[col].isnull().sum() > 0:
        
        if df_test[col].dtype == 'float64':

            val = df_test[col].median()
        else:

            val = df_test[col].mode()[0]  #the most frequent value
        

        df_test[col] = df_test[col].fillna(val)


df_test.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Encoding

# %%
df_test.replace({'Yes':1, 'No':0}, inplace=True)

#print("WindGustDir: ", df['WindGustDir'].unique())

#WindGustDir   WindDir9am	WindDir3pm
df_test['WindGustDir'] = pd.factorize(df_test['WindGustDir'])[0] + 1
df_test['WindDir9am'] = pd.factorize(df_test['WindDir9am'])[0] + 1
df_test['WindDir3pm'] = pd.factorize(df_test['WindDir3pm'])[0] + 1

#City:
df_test['City'] = pd.factorize(df_test['City'])[0] + 1

#Date : extracting each component
df_test['Date'] = pd.to_datetime(df_test['Date'])

#year, month, day as separate features
df_test['Year'] = df_test['Date'].dt.year
df_test['Month'] = df_test['Date'].dt.month
df_test['Day'] = df_test['Date'].dt.day

#df_test['Season'] = df_test['Month'].apply(get_season)

df_test = df_test.drop('Date', axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4976\520747010.py:1: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %% [markdown]
# Predicting

# %%
test_preds = best_xgb_model.predict(df_test)

prediction_distribution = pd.Series(test_preds).value_counts()

print(prediction_distribution)
# Out:
# 0    23767
# 1     8550
# Name: count, dtype: int64

# %% [markdown]
# Saving the results

# %%
df_test['RainTomorrow'] = test_preds
new_df = pd.read_csv("test.csv")

df_test = df_test[['Day', 'RainTomorrow']]
df_test['Day'] = new_df['Day']
df_test['RainTomorrow'] = df_test['RainTomorrow'].replace({0: 'No', 1: 'Yes'})
df_test.to_csv('rain_pred.csv', index=False)
df_test
# Out:
#           Day RainTomorrow
# 0       76672           No
# 1       76673           No
# 2       76674           No
# 3       76675           No
# 4       76676           No
# ...       ...          ...
# 32312  108984          Yes
# 32313  108985          Yes
# 32314  108986          Yes
# 32315  108987          Yes
# 32316  108988          Yes
#
# [32317 rows x 2 columns]
